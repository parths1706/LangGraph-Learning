# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
from dotenv import load_dotenv
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: str | ForwardRef('os.PathLike[str]') | None = None, stream: IO[str] | None = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: str | None = 'utf-8') -> bool>

# %%
# Initialize ChatGroq model
# Common models: "llama-3.3-70b-versatile", "llama-3.1-8b-instant", "mixtral-8x7b-32768"
model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class BlogState(TypedDict):
    
    title : str
    outline :str
    content :str

# %%
def create_outline(state:BlogState) -> BlogState:

    #fetch title 
    title = state["title"]

    #call llm gen outline
    prompt = f"Generate a detailed outline for a blog on the topic -{title}"
    outline = model.invoke(prompt).content

    #update state

    state["outline"] =outline


    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Importance of AI in India\'s economic growth and development\n* Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and a growing talent pool.\n\n**II. Current State of AI in India**\n\n* Overview of India\'s AI landscape, including key industries and sectors where AI is being adopted (e.g., healthcare, finance, manufacturing)\n* Discussion of notable AI-powered projects and initiatives in India (e.g., chatbots, virtual assistants, predictive analytics)\n* Statistics on AI adoption in India, including investment, job creation, and revenue growth\n\n**III. Government Initiatives and Support**\n\n* Overview of government initiatives to promote AI adoption in India, such as:\n\t+ National AI Mission (NIM)\n\t+ AI Task Force\n\t+ Digital India initiative\n* Discussion of government funding and incentives for AI startups and research institutions\n* Examples of government-led AI projects, such as AI-powered healthcare systems and smart city initiatives\n\n**IV. Technological Advancements and Infrastructure**\n\n* Discussion of technological advancements driving AI adoption in India, such as:\n\t+ Cloud computing\n\t+ Big data analytics\n\t+ Internet of Things (IoT)\n* Overview of India\'s AI infrastructure, including data centers, research institutions, and innovation hubs\n* Examples of Indian companies developing AI-powered technologies, such as natural language processing and computer vision\n\n**V. Talent Pool and Education**\n\n* Discussion of India\'s growing talent pool in AI, including:\n\t+ Skilled professionals in AI and related fields\n\t+ AI education and training programs in Indian universities and institutions\n* Overview of initiatives to promote AI education and skill development, such as:\n\t+ Online courses and certification programs\n\t+ AI research grants and fellowships\n* Examples of Indian universities and institutions offering AI-related programs and courses\n\n**VI. Challenges and Opportunities**\n\n* Discussion of challenges facing AI adoption in India, such as:\n\t+ Data quality and availability\n\t+ Regulatory frameworks and ethics\n\t+ Job displacement and skill gaps\n* Overview of opportunities for AI adoption in India, such as:\n\t+ Improving healthcare outcomes\n\t+ Enhancing customer experience\n\t+ Increasing efficiency and productivity\n* Examples of Indian companies leveraging AI to drive business growth and innovation\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India and its potential impact on the economy and society\n* Future outlook for AI in India, including potential areas of growth and development\n* Call to action: Encouraging readers to explore AI opportunities and contribute to India\'s AI ecosystem.\n\n**VIII. Additional Resources**\n\n* List of additional resources, such as:\n\t+ AI-related research papers and reports\n\t+ Online courses and certification programs\n\t+ AI-related events and conferences in India\n* Links to relevant websites and social media channels for further information and updates.\n\nThis outline provides a comprehensive structure for a blog on the rise of AI in India, covering key aspects such as government initiatives, technological advancements, talent pool, and challenges and opportunities.', 'content': "**Rise of AI in India: A Comprehensive Overview**\n\n**Introduction**\n\nArtificial Intelligence (AI) has been gaining significant attention globally, and its importance cannot be overstated. AI has the potential to revolutionize various industries, transform the way we live and work, and contribute to a country's economic growth and development. India, being one of the fastest-growing economies in the world, is no exception. The Indian g ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Importance of AI in India's economic growth and development
# * Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and a growing talent pool.
#
# **II. Current State of AI in India**
#
# * Overview of India's AI landscape, including key industries and sectors where AI is being adopted (e.g., healthcare, finance, manufacturing)
# * Discussion of notable AI-powered projects and initiatives in India (e.g., chatbots, virtual assistants, predictive analytics)
# * Statistics on AI adoption in India, including investment, job creation, and revenue growth
#
# **III. Government Initiatives and Support**
#
# * Overview of government initiatives to promote AI adoption in India, such as:
# 	+ National AI Mission (NIM)
# 	+ AI Task Force
# 	+ Digital India initiative
# * Discussion of government funding and incentives for AI startups and research institutions
# * Examples of government-led AI projects, such as AI-powered healthcare systems and smart city initiatives
#
# **IV. Technological Advancements and Infrastructure**
#
# * Discussion of technological advancements driving AI adoption in India, such as:
# 	+ Cloud computing
# 	+ Big data analytics
# 	+ Internet of Things (IoT)
# * Overview of India's AI infrastructure, including data centers, research institutions, and innovation hubs
# * Examples of Indian companies developing AI-powered technologies, such as natural language processing and computer vision
#
# **V. Talent Pool and Education**
#
# * Discussion of India's growing talent pool in AI, including:
# 	+ Skilled professionals in AI and related fields
# 	+ AI education and training programs in Indian universities and institutions
# * Overview of initiatives to promote AI education and skill development, such as:
# 	+ Online courses and certification programs
# 	+ AI research grants and fellowships
# * Examples of Indian universities and institutions offering AI-related programs and courses
#
# **VI. Challenges and Opportunities**
#
# * Discussion of challenges facing AI adoption in India, such as:
# 	+ Data quality and availability
# 	+ Regulatory frameworks and ethics
# 	+ Job displacement and skill gaps
# * Overview of opportunities for AI adoption in India, such as:
# 	+ Improving healthcare outcomes
# 	+ Enhancing customer experience
# 	+ Increasing efficiency and productivity
# * Examples of Indian companies leveraging AI to drive business growth and innovation
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India and its potential impact on the economy and society
# * Future outlook for AI in India, including potential areas of growth and development
# * Call to action: Encouraging readers to explore AI opportunities and contribute to India's AI ecosystem.
#
# **VIII. Additional Resources**
#
# * List of additional resources, such as:
# 	+ AI-related research papers and reports
# 	+ Online courses and certification programs
# 	+ AI-related events and conferences in India
# * Links to relevant websites and social media channels for further information and updates.
#
# This outline provides a comprehensive structure for a blog on the rise of AI in India, covering key aspects such as government initiatives, technological advancements, talent pool, and challenges and opportunities.

# %%
print(final_state['content'])
# Out:
# **Rise of AI in India: A Comprehensive Overview**
#
# **Introduction**
#
# Artificial Intelligence (AI) has been gaining significant attention globally, and its importance cannot be overstated. AI has the potential to revolutionize various industries, transform the way we live and work, and contribute to a country's economic growth and development. India, being one of the fastest-growing economies in the world, is no exception. The Indian government has recognized the potential of AI and has been actively promoting its adoption across various sectors. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool. As we delve into the world of AI in India, it becomes clear that the country is witnessing a significant surge in AI adoption, and this trend is expected to continue in the coming years.
#
# **Current State of AI in India**
#
# India's AI landscape is rapidly evolving, with key industries such as healthcare, finance, and manufacturing being at the forefront of AI adoption. Notable AI-powered projects and initiatives in India include chatbots, virtual assistants, and predictive analytics. According to a report by Nasscom, the AI market in India is expected to reach $7.8 billion by 2025, growing at a CAGR of 30.8%. The report also states that the AI industry in India has created over 100,000 jobs and is expected to create over 200,000 more jobs by 2025. Furthermore, AI has the potential to increase India's GDP by 1.3% by 2025, which is a significant contribution to the country's economic growth.
#
# Some notable examples of AI adoption in India include:
#
# * HDFC Bank's chatbot, which uses AI to provide customer support and answer queries
# * Flipkart's AI-powered recommendation engine, which suggests products to customers based on their shopping history and preferences
# * The Indian Railways' AI-powered predictive maintenance system, which helps to reduce delays and improve efficiency
#
# **Government Initiatives and Support**
#
# The Indian government has been actively promoting AI adoption across various sectors through several initiatives. Some of the notable initiatives include:
#
# * **National AI Mission (NIM)**: Launched in 2020, NIM aims to promote AI adoption in India by providing funding, infrastructure, and talent support.
# * **AI Task Force**: Set up in 2017, the AI Task Force is responsible for promoting AI adoption in India and providing recommendations to the government on AI-related policies.
# * **Digital India initiative**: Launched in 2015, the Digital India initiative aims to promote digital literacy and digital infrastructure in India, which is essential for AI adoption.
#
# The government has also provided funding and incentives for AI startups and research institutions. For example, the government has allocated ₹1,500 crores for AI research and development under the NIM. Additionally, the government has launched several AI-related programs, such as the AI for All program, which aims to promote AI education and skill development.
#
# **Technological Advancements and Infrastructure**
#
# Technological advancements such as cloud computing, big data analytics, and Internet of Things (IoT) have been driving AI adoption in India. Cloud computing, for example, has made it possible for companies to store and process large amounts of data, which is essential for AI. Big data analytics has enabled companies to analyze and gain insights from large amounts of data, which is critical for AI-powered decision-making. IoT has enabled companies to connect devices and sensors, which is essential for AI-powered automation.
#
# India's AI infrastructure is also rapidly developing, with several data centers, research institutions, and innovation hubs being set up across the country. Some notable examples include:
#
# * **NASSCOM's AI Centre of Excellence**: Set up in Bengaluru, this center provides funding, mentorship, and infrastructure support to AI startups.
# * **IIT Bombay's AI Research Centre**: Set up in 2019, this center provides funding, infrastructure, and talent support for AI research and development.
# * **T-Hub**: Set up in Hyderabad, T-Hub is a startup incubator that provides funding, mentorship, and infrastructure support to AI startups.
#
# **Talent Pool and Education**
#
# India has a growing talent pool in AI, with several skilled professionals in AI and related fields such as machine learning, data science, and computer vision. According to a report by LinkedIn, India has the second-largest talent pool in AI, after the United States.
#
# Several Indian universities and institutions are offering AI-related programs and courses, such as:
#
# * **IIT Delhi's AI and Machine Learning program**: This program provides students with a comprehensive education in AI and machine learning.
# * **IIIT Hyderabad's AI and Data Science program**: This program provides students with a comprehensive education in AI and data science.
# * **NASSCOM's AI and Machine Learning certification program**: This program provides professionals with a comprehensive education in AI and machine learning.
#
# **Challenges and Opportunities**
#
# Despite the rapid growth of AI in India, there are several challenges that need to be addressed. Some of the notable challenges include:
#
# * **Data quality and availability**: High-quality data is essential for AI, but India lacks a robust data infrastructure.
# * **Regulatory frameworks and ethics**: There is a need for clear regulatory frameworks and ethics guidelines for AI adoption in India.
# * **Job displacement and skill gaps**: AI has the potential to displace jobs, and there is a need for re-skilling and up-skilling of the workforce.
#
# However, there are also several opportunities for AI adoption in India, such as:
#
# * **Improving healthcare outcomes**: AI can help improve healthcare outcomes by analyzing medical data and providing personalized treatment recommendations.
# * **Enhancing customer experience**: AI can help enhance customer experience by providing personalized recommendations and improving customer support.
# * **Increasing efficiency and productivity**: AI can help increase efficiency and productivity by automating repetitive tasks and providing insights for decision-making.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that has the potential to transform the country's economy and society. With government initiatives, technological advancements, and a growing talent pool, India is well on its way to becoming a leader in AI adoption. However, there are also several challenges that need to be addressed, such as data quality and availability, regulatory frameworks and ethics, and job displacement and skill gaps. As we move forward, it is essential to address these challenges and leverage the opportunities that AI provides.
#
# **Future Outlook**
#
# The future outlook for AI in India is promising, with several potential areas of growth and development. Some of the potential areas of growth include:
#
# * **AI-powered healthcare**: AI has the potential to transform the healthcare industry in India by improving healthcare outcomes and providing personalized treatment recommendations.
# * **AI-powered finance**: AI has the potential to transform the finance industry in India by improving risk management and providing personalized financial recommendations.
# * **AI-powered education**: AI has the potential to transform the education industry in India by providing personalized learning recommendations and improving student outcomes.
#
# To leverage these opportunities, it is essential to invest in AI research and development, promote AI education and skill development, and provide funding and infrastructure support to AI startups and research institutions.
#
# **Call to Action**
#
# As we conclude this blog, we encourage readers to explore AI opportunities and contribute to India's AI ecosystem. Whether you are a student, a professional, or an entrepreneur, there are several ways to get involved in AI, such as:
#
# * **Taking online courses and certification programs**: There are several online courses and certification programs available that can help you develop AI skills and knowledge.
# * **Participating in AI-related events and conferences**: There are several AI-related events and conferences that take place in India, which can provide you with an opportunity to network with AI professionals and learn about the latest AI trends and developments.
# * **Joining AI-related communities and forums**: There are several AI-related communities and forums available that can provide you with an opportunity to connect with AI professionals and learn about the latest AI trends and developments.
#
# **Additional Resources**
#
# For further information and updates on AI in India, we recommend the following resources:
#
# * **NASSCOM's AI report**: This report provides a comprehensive overview of the AI industry in India, including trends, challenges, and opportunities.
# * **AI-related research papers and reports**: There are several research papers and reports available that provide insights into AI adoption in India, including challenges, opportunities, and future outlook.
# * **Online courses and certification programs**: There are several online courses and certification programs available that can help you develop AI skills and knowledge.
# * **AI-related events and conferences**: There are several AI-related events and conferences that take place in India, which can provide you with an opportunity to network with AI professionals and learn about the latest AI trends and developments.
# * **AI-related communities and forums**: There are several AI-related communities and forums available that can provide you with an opportunity to connect with AI professionals and learn about the latest AI trends and developments.
#
# Some notable AI-related events and conferences in India include:
#
# * **NASSCOM's AI Summit**: This summit brings together AI professionals and industry leaders to discuss the latest AI trends and developments.
# * **IIT Bombay's AI Conference**: This conference provides a platform for AI researchers and professionals to share their research and knowledge.
# * **T-Hub's AI Meetup**: This meetup provides a platform for AI professionals and entrepreneurs to network and learn about the latest AI trends and developments.
#
# We hope that this blog has provided you with a comprehensive overview of the rise of AI in India and its potential impact on the economy and society. We encourage you to explore AI opportunities and contribute to India's AI ecosystem.
